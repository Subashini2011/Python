# %%
import random as r
class employee():
    def dep1(self):
        for i in range(1,7):
            fd = r.randint(1,5000)
            print("dep1 ID's  : ",fd)
        if(i>=10):
            print("validated 10 or more persons for dep 1")                
        else:
            print("validated less than 10 id's in dep1")
    def dep2(self):
        for i in range(1,11):
            fd = r.randint(1,5000)
            print("dep2 ID's  : ",fd)
        if(i>=10):
            print("validated 10 or more persons for dep 2")                
        else:
            print("validated less than 10 id's in dep2")
    def dep3(self):
        for i in range(1,12):
            fd = r.randint(1,5000)
            print("dep3 ID's  : ",fd)
        if(i>=10):
            print("validated 10 or more persons for dep 3")                
        else:
            print("validated less than 10 id's in dep3")
    def dep4(self):
        for i in range(1,11):
            fd = r.randint(1,5000)
            print("dep4 ID's  : ",fd)
        if(i>=10):
            print("validated 10 or more persons for dep 4")                
        else:
            print("validated less than 10 id's in dep4")
    def dep5(self):
        for i in range(1,2):
            fd = r.randint(1,5000)
            print("dep5 ID's  : ",fd)
        if(i>=10):
            print("validated 10 or more persons for dep 5")                
        else:
            print("validated less than 10 id's in dep5")
f= employee()  
f.dep1()
f.dep2()
f.dep3()
f.dep4()
f.dep5()
# Out:
# dep1 ID's  :  4726
# dep1 ID's  :  1817
# dep1 ID's  :  2041
# dep1 ID's  :  1558
# dep1 ID's  :  3479
# dep1 ID's  :  3911
# validated less than 10 id's in dep1
# dep2 ID's  :  4009
# dep2 ID's  :  1317
# dep2 ID's  :  1434
# dep2 ID's  :  1380
# dep2 ID's  :  2331
# dep2 ID's  :  10
# dep2 ID's  :  4715
# dep2 ID's  :  762
# dep2 ID's  :  3453
# dep2 ID's  :  4665
# validated 10 or more persons for dep 2
# dep3 ID's  :  1588
# dep3 ID's  :  1208
# dep3 ID's  :  756
# dep3 ID's  :  2681
# dep3 ID's  :  2809
# dep3 ID's  :  2517
# dep3 ID's  :  1298
# dep3 ID's  :  2411
# dep3 ID's  :  3882
# dep3 ID's  :  4221
# dep3 ID's  :  3103
# validated 10 or more persons for dep 3
# dep4 ID's  :  2194
# dep4 ID's  :  2101
# dep4 ID's  :  1369
# dep4 ID's  :  1162
# dep4 ID's  :  3619
# dep4 ID's  :  613
# dep4 ID's  :  534
# dep4 ID's  :  3854
# dep4 ID's  :  2478
# dep4 ID's  :  3203
# validated 10 or more persons for dep 4
# dep5 ID's  :  1409
# validated less than 10 id's in dep5
